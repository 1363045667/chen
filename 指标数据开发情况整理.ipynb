# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('mysql+pymysql://sitech:Huawei_123@172.22.144.168:3310/my_sitech')

# %%
sql = ''' select index_id,index_name,period,sum(Current_val),sum(Pervious_val),sum(Month_cum_val),sum(Year_cum_val),sum(last_month_period),sum(last_year_period) from dws_index_value_base_info where stat_date = '2021-02-02' group by Index_ID,period; '''

# %%
df = pd.read_sql_query(sql, engine)

# %%
df.columns[3:9]
# Out:
# Index(['sum(Current_val)', 'sum(Pervious_val)', 'sum(Month_cum_val)',
#        'sum(Year_cum_val)', 'sum(last_month_period)', 'sum(last_year_period)'],
#       dtype='object')

# %%
length = len(df)
columns = ['当期值','上期值','月累计','年累计','上月同期累计','上年同期累计']
for i,j in zip(df.columns[3:],range(len(df.columns[3:]))):
    df[i] = df[i].apply(lambda x : '' if x == 0 or pd.isnull(x) else columns[j] )

# %%
df
# Out:
#          index_id             index_name period sum(Current_val)  \
# 0           D0002      mCloud业务计费收入目标完成率      月
# 1           D0044            英国方向MVNO客户数      日              当期值
# 2           D0045            日本方向MVNO客户数      日              当期值
# 3           D0046           新加坡方向MVNO客户数      日              当期值
# 4           D0047           加拿大方向MVNO客户数      日              当期值
# 5           D0048            泰国方向MVNO客户数      日              当期值
# 6           D0049           英国方向MVNO业务收入      月
# 7           D0050           日本方向MVNO业务收入      月
# 8           D0051          新加坡方向MVNO业务收入      月
# 9           D0052          加拿大方向MVNO业务收入      月
# 10          D0053           泰国方向MVNO业务收入      月
# 11          D0056              MVNO新增客户数      日              当期值
# 12          D0056              MVNO新增客户数      月              当期值
# 13          D0070           澳大利亚业务类KPI得分      日              当期值
# 14          D0071            菲律宾业务类KPI得分      日              当期值
# ...

# %%
df['show_val'] = ''

# %%
for i in df.columns[3:9]:
    for j in range(len(df)):
        if df.ix[j,i] != '':
            if df.ix[j,'show_val'] == '':
                df.ix[j,'show_val'] = df.ix[j,'show_val']+df.ix[j,i]
            else:
                df.ix[j,'show_val'] = df.ix[j,'show_val']+','+df.ix[j,i]
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# ...

# %%
df[['index_id','index_name','period','show_val']].to_excel('D:\\思特奇\\工作文件\\最小指标库\\最小指标前段展示值情况.xlsx',index = False)
